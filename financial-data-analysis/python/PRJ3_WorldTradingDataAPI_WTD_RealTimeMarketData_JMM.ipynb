# %%
# WORLD TRADING DATA (WTD) - INTRODUCTION:
# https://www.worldtradingdata.com/documentation?python#introduction

# World Trading Data database of supported stocks and indices:
# https://www.worldtradingdata.com/search

# World Trading Data database of supported forex pairs:
# https://www.worldtradingdata.com/search/forex

# %%
# WTD - AUTHENTICATION:
# Each API request is authenticated with your own personal API token.
# Include your API token in each request by passing it as a query parameter in each request.

# Register for a World Trading Data API Key:
# https://www.worldtradingdata.com/register

# Please update the "api_keys.py" configuration file with your personal API Key from World Trading Data.

# Import API Keys:
from api_keys import world_trading_data_api_token

# %%
# WTD - REAL TIME MARKET DATA:

# HTTP Request:
# GET https://api.worldtradingdata.com/api/v1/stock

# Query Parameters:
# The endpoint takes up to 5 query parameters: symbol, api_token, sort_order, sort_by and output.
# The symbol parameter allows you to request real time data.
# The output=csv parameter will return the data as a CSV format but by default will return JSON.
# The api_token is used to verify each request.

# Required Parameters: symbol; api_token
# Example: symbol=SNAP, TWTR, VOD.L; my_api_token

# Optional Parameters: sort_order, sort_by, output
# Example: sort_order=desc/asc, sort_by=name/symbol/list_order, output=json/csv

# %%
# WTD - REAL TIME MARKET DATA:

# Full History:
# World Trading Data's real time data endpoint returns the nearest trading data for stocks and indexes worldwide.

# Top 30 largest US financial companies 2020:
# https://disfold.com/top-us-financial-companies/

# Top 25 (of the above 30) Financial Stocks Available from the World Trading Data API:
#1. Berkshire Hathaway - 'BRK.B'
#2. JPMorgan Chase - 'JPM'
#3. Bank of America - 'BAC'
#4. Wells Fargo - 'WFC'
#5. Citigroup - 'C'
#6. American Express - 'AXP'
#7. Morgan Stanley - 'MS'
#8. BlackRock - 'BLK'
#9. U.S. Bancorp - 'USB'
#10. Goldman Sachs - 'GS'
#11. Truist Financial - 'TFC'
#12. Chubb - 'CB'
#13. S&P Global - 'SPGI'
#14. PNC Financial Services - 'PNC'
#15. Charles Schwab - 'SCHW'
#16. Marsh & McLennan - 'MMC'
#17. Aon - 'AON'
#18. Intercontinental Exchange - 'ICE'
#19. Moody’s - 'MCO'
#20. Progressive - 'PGR'
#21. MetLife - 'MET'
#22. American International Group - 'AIG'
#23. Capital One - 'COF'
#24. The Bank of New York Mellon - 'BK'
#25. Allstate Corp - 'ALL'

# %%
# WTD - REAL TIME MARKET DATA - SECTION #1:

# Stock and Index Real Time:
# World Trading Data's real time data endpoint returns the nearest trading data for stocks and indexes worldwide.
# The endpoint allows up to 500 stocks or indexes to be returned with each request.

# 25 Financial Stocks Available from the World Trading Data API:
# Set #1:    'BRK.B,JPM,BAC,WFC,C'
# Set #2:    'AXP,MS,BLK,USB,GS'
# Set #3:    'TFC,CB,SPGI,PNC,SCHW'
# Set #4:    'MMC,AON,ICE,MCO,PGR'
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API NOTE:
# Currently using the free version of the World Trading Data API.
# (maximum of 5 ticker symbols per request)
# Pricing: https://www.worldtradingdata.com/pricing

# WTD - API - Real Time Market Data - Dependencies & Setup:
import requests
import json   # or import "simplejson" as json if using Python version < vs. 2.6 (earlier than vs. 2.6)
import csv
import pandas as pd
from pytz import utc, timezone
from datetime import datetime
from time import mktime

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #1: 'symbol': 'BRK.B,JPM,BAC,WFC,C',
params = {'symbol': 'BRK.B,JPM,BAC,WFC,C',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - API Output, "stocks_response_api" - Raw & Un-modified:
stocks_response_api
# Out:
# <Response [200]>

# %%
# WTD - API Output, "stocks_response_api" - Data Type:
type(stocks_response_api)
# Out:
# requests.models.Response

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'BAC',
#    'name': 'Bank of America Corporation',
#    'currency': 'USD',
#    'price': '20.57',
#    'price_open': '19.65',
#    'day_high': '20.79',
#    'day_low': '19.59',
#    '52_week_high': '35.72',
#    '52_week_low': '17.95',
#    'day_change': '0.80',
#    'change_pct': '4.05',
#    'close_yesterday': '19.77',
#    'market_cap': '179468517376',
#    'volume': '69192886',
#    'volume_avg': '117991112',
#    'shares': '8724769792',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '7.48',
#    'eps': '2.75'},
#   {'symbol': 'BRK.B',
#    'name': 'Berkshire Hathaway Inc.',
#    'currency': 'USD',
#    'price': '179.73',
#    'price_open': '175.00',
#    'day_high': '180.31',
#    'day_low': '174.23',
#    '52_week_high': '231.61',
#    '52_week_low': '159.50',
#    'day_change': '3.78',
#    'change_pct': '2.15',
#    'close_yesterday': '175.95',
#    'market_cap': '435020300288',
#    'volume': '7125265',
#    'volume_avg': '11771350',
#    'shares': '1382349952',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '0.00',
#    'eps': '49828.45'},
#   {'symbol': 'C',
#    'name': 'Citigroup Inc.',
#    'currency': 'USD',
#    'price': '39.23',
#    'price_open': '38.36',
#    'day_high': '39.66',
#    'day_low': '37.30',
#    '52_week_high': '83.11',
#    '52_week_low': '32.00',
#    'day_change': '0.72',
#    'change_pct': '1.87',
#    'close_yesterday': '38.51',
#    'market_cap': '82312781824',
#    'volume': '28700869',
#    'volume_avg': '30651662',
#    'shares': '2098210048',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '4.88',
#    'eps': '8.04'},
#   {'symbol': 'JPM',
#    'name': 'JPMorgan Chase & Co.',
#    'currency': 'USD',
#    'price': '87.51',
#    'price_open': '83.51',
#    'day_high': '87.91',
#    'day_low': '82.96',
#    '52_week_high': '141.10',
#    '52_week_low': '76.91',
#    'day_change': '3.15',
#    'change_pct': '3.73',
#    'close_yesterday': '84.36',
#    'market_cap': '269003980800',
#    'volume': '23386199',
#    'volume_avg': '29739350',
#    'shares': '3084000000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '8.16',
#    'eps': '10.72'},
#   {'symbol': 'WFC',
#    'name': 'Wells Fargo & Company',
#    'currency': 'USD',
#    'price': '27.22',
#    'price_open': '26.47',
#    'day_high': '27.53',
#    'day_low': '26.40',
#    '52_week_high': '54.75',
#    '52_week_low': '25.11',
#    'day_change': '0.65',
#    'change_pct': '2.45',
#    'close_yesterday': '26.57',
#    'market_cap': '111313469440',
#    'volume': '27969795',
#    'volume_avg': '45007400',
#    'shares': '4089400064',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '6.72',
#    'eps': '4.05'}]}

# %%
# WTD - API Output, "stocks_response_json" - Data Type:
type(stocks_response_json)
# Out:
# dict

# %%
# # ***NOTE: Not currently using this block of code!***
# # The JSON Dictionary API Output, "stocks_response_json", is provided "pre-sorted" in chronological order,
# # by date, from NEWEST to OLDEST.

# # Sort JSON Dictionary, "stocks_response_json", in chronological order, by date, from OLDEST to NEWEST:
# # (sorting JSON dictionary keys in ascending order)
# stocks_response_json_sorted = json.dumps(stocks_response_json, indent = 4, sort_keys = True)
# print(stocks_response_json_sorted)

# %%
# # WTD - JSON String (appears as a "pretty print" JSON Dictionary), "stocks_response_json_sorted" - Data Type:
# type(stocks_response_json_sorted)

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__BRKB_JPM_BAC_WFC_C__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_one = ['BRK.B', 'JPM', 'BAC', 'WFC', 'C']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_one:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Print the "stocks_response_json_list" to confirm it is currently FULL of data items:
print(stocks_response_json_list)
# Out:
# [['BAC', 'Bank of America Corporation', 'USD', '20.57', '19.65', '20.79', '19.59', '35.72', '17.95', '0.80', '4.05', '19.77', '179468517376', '69192886', '117991112', '8724769792', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-04-02 16:02:00', '7.48', '2.75'], ['BRK.B', 'Berkshire Hathaway Inc.', 'USD', '179.73', '175.00', '180.31', '174.23', '231.61', '159.50', '3.78', '2.15', '175.95', '435020300288', '7125265', '11771350', '1382349952', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-04-02 16:02:00', '0.00', '49828.45'], ['C', 'Citigroup Inc.', 'USD', '39.23', '38.36', '39.66', '37.30', '83.11', '32.00', '0.72', '1.87', '38.51', '82312781824', '28700869', '30651662', '2098210048', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-04-02 16:02:00', '4.88', '8.04'], ['JPM', 'JPMorgan Chase & Co.', 'USD', '87.51', '83.51', '87.91', '82.96', '141.10', '76.91', '3.15', '3.73', '84.36', '269003980800', '23386199', '29739350', '3084000000', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-04-02 16:02:00', '8.16', '10.72'], ['WFC', 'Wells Fargo & Company', 'USD', '27.22', '26.47', '27.53', '26.40', '54.75', '25.11', '0.65', '2.45', '26.57', '111313469440', '27969795', '45007400', '4089400064', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-04-02 16:02:00', '6.72', '4.05']]

# %%
# Create "stocks_response_json_list_one_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_one_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_one_df" DataFrame columns:
stocks_response_json_list_one_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_one_df
# Out:
#   symbol                         name currency   price price_open day_high  \
# 0    BAC  Bank of America Corporation      USD   20.57      19.65    20.79
# 1  BRK.B      Berkshire Hathaway Inc.      USD  179.73     175.00   180.31
# 2      C               Citigroup Inc.      USD   39.23      38.36    39.66
# 3    JPM         JPMorgan Chase & Co.      USD   87.51      83.51    87.91
# 4    WFC        Wells Fargo & Company      USD   27.22      26.47    27.53
#
#   day_low 52_week_high 52_week_low day_change  ... volume_avg      shares  \
# 0   19.59        35.72       17.95       0.80  ...  117991112  8724769792
# 1  174.23       231.61      159.50       3.78  ...   11771350  1382349952
# 2   37.30        83.11       32.00       0.72  ...   30651662  2098210048
# 3   82.96       141.10       76.91       3.15  ...   29739350  3084000000
# 4   26.40        54.75       25.11       0.65  ...   45007400  4089400064
#
#        stock_exchange_long stock_exchange_short timezone     timezone_name  \
# 0  New York Stock Exchange                 NYSE      EDT  America/New_York
# 1  New York Stock Exchange                 NYSE      EDT  America/New_York
# 2  New York Stock Exchange                 NYSE      EDT  America/New_York
# 3  New York Stock Exchange                 NYSE      EDT  America/New_York
# 4  New York Stock Exchange                 NYSE      EDT  America/New_York
#
#   gmt_offset      last_trade_time    pe       eps
# 0     -14400  2020-04-02 16:02:00  7.48      2.75
# 1     -14400  2020-04-02 16:02:00  0.00  49828.45
# 2     -14400  2020-04-02 16:02:00  4.88      8.04
# 3     -14400  2020-04-02 16:02:00  8.16     10.72
# 4     -14400  2020-04-02 16:02:00  6.72      4.05
#
# [5 rows x 24 columns]

# %%
# REAL TIME MARKET DATA - SECTION #2:
# Set #2:    'AXP,MS,BLK,USB,GS'
# Set #3:    'TFC,CB,SPGI,PNC,SCHW'
# Set #4:    'MMC,AON,ICE,MCO,PGR'
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #2: 'symbol': 'AXP,MS,BLK,USB,GS',
params = {'symbol': 'AXP,MS,BLK,USB,GS',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'AXP',
#    'name': 'American Express Company',
#    'currency': 'USD',
#    'price': '76.66',
#    'price_open': '77.06',
#    'day_high': '79.12',
#    'day_low': '75.83',
#    '52_week_high': '138.13',
#    '52_week_low': '67.00',
#    'day_change': '-0.75',
#    'change_pct': '-0.97',
#    'close_yesterday': '77.41',
#    'market_cap': '61770944512',
#    'volume': '8203136',
#    'volume_avg': '8369462',
#    'shares': '805777984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '9.59',
#    'eps': '7.99'},
#   {'symbol': 'BLK',
#    'name': 'BlackRock, Inc.',
#    'currency': 'USD',
#    'price': '426.53',
#    'price_open': '408.18',
#    'day_high': '433.87',
#    'day_low': '406.19',
#    '52_week_high': '576.81',
#    '52_week_low': '323.98',
#    'day_change': '16.99',
#    'change_pct': '4.15',
#    'close_yesterday': '409.54',
#    'market_cap': '66450812928',
#    'volume': '622890',
#    'volume_avg': '1383250',
#    'shares': '154828000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '15.00',
#    'eps': '28.43'},
#   {'symbol': 'GS',
#    'name': 'The Goldman Sachs Group, Inc.',
#    'currency': 'USD',
#    'price': '149.93',
#    'price_open': '143.02',
#    'day_high': '150.45',
#    'day_low': '141.67',
#    '52_week_high': '250.46',
#    '52_week_low': '130.85',
#    'day_change': '4.64',
#    'change_pct': '3.19',
#    'close_yesterday': '145.29',
#    'market_cap': '51557023744',
#    'volume': '4378700',
#    'volume_avg': '5510687',
#    'shares': '343873984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '7.13',
#    'eps': '21.03'},
#   {'symbol': 'MS',
#    'name': 'Morgan Stanley',
#    'currency': 'USD',
#    'price': '33.90',
#    'price_open': '31.34',
#    'day_high': '34.00',
#    'day_low': '31.25',
#    '52_week_high': '57.57',
#    '52_week_low': '27.20',
#    'day_change': '2.28',
#    'change_pct': '7.21',
#    'close_yesterday': '31.62',
#    'market_cap': '51948363776',
#    'volume': '20713780',
#    'volume_avg': '24777962',
#    'shares': '1532400000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '6.53',
#    'eps': '5.19'},
#   {'symbol': 'USB',
#    'name': 'U.S. Bancorp',
#    'currency': 'USD',
#    'price': '32.67',
#    'price_open': '31.60',
#    'day_high': '33.08',
#    'day_low': '31.45',
#    '52_week_high': '61.11',
#    '52_week_low': '28.59',
#    'day_change': '0.74',
#    'change_pct': '2.32',
#    'close_yesterday': '31.93',
#    'market_cap': '49699561472',
#    'volume': '8166987',
#    'volume_avg': '13092125',
#    'shares': '1521260032',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '7.85',
#    'eps': '4.16'}]}

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__AXP_MS_BLK_USB_GS__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_two = ['AXP', 'MS', 'BLK', 'USB', 'GS']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_two:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Create "stocks_response_json_list_two_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_two_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_two_df" DataFrame columns:
stocks_response_json_list_two_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_two_df
# Out:
#   symbol                           name currency   price price_open day_high  \
# 0    AXP       American Express Company      USD   76.66      77.06    79.12
# 1    BLK                BlackRock, Inc.      USD  426.53     408.18   433.87
# 2     GS  The Goldman Sachs Group, Inc.      USD  149.93     143.02   150.45
# 3     MS                 Morgan Stanley      USD   33.90      31.34    34.00
# 4    USB                   U.S. Bancorp      USD   32.67      31.60    33.08
#
#   day_low 52_week_high 52_week_low day_change  ... volume_avg      shares  \
# 0   75.83       138.13       67.00      -0.75  ...    8369462   805777984
# 1  406.19       576.81      323.98      16.99  ...    1383250   154828000
# 2  141.67       250.46      130.85       4.64  ...    5510687   343873984
# 3   31.25        57.57       27.20       2.28  ...   24777962  1532400000
# 4   31.45        61.11       28.59       0.74  ...   13092125  1521260032
#
#        stock_exchange_long stock_exchange_short timezone     timezone_name  \
# 0  New York Stock Exchange                 NYSE      EDT  America/New_York
# 1  New York Stock Exchange                 NYSE      EDT  America/New_York
# 2  New York Stock Exchange                 NYSE      EDT  America/New_York
# 3  New York Stock Exchange                 NYSE      EDT  America/New_York
# 4  New York Stock Exchange                 NYSE      EDT  America/New_York
#
#   gmt_offset      last_trade_time     pe    eps
# 0     -14400  2020-04-02 16:02:00   9.59   7.99
# 1     -14400  2020-04-02 16:02:00  15.00  28.43
# 2     -14400  2020-04-02 16:02:00   7.13  21.03
# 3     -14400  2020-04-02 16:02:00   6.53   5.19
# 4     -14400  2020-04-02 16:02:00   7.85   4.16
#
# [5 rows x 24 columns]

# %%
# Append "stocks_response_json_list_two_df" to the end of "stocks_response_json_list_one_df":
appended_one_thru_two_df = stocks_response_json_list_one_df.append(stocks_response_json_list_two_df, ignore_index = True)
appended_one_thru_two_df
# Out:
#   symbol                           name currency   price price_open day_high  \
# 0    BAC    Bank of America Corporation      USD   20.57      19.65    20.79
# 1  BRK.B        Berkshire Hathaway Inc.      USD  179.73     175.00   180.31
# 2      C                 Citigroup Inc.      USD   39.23      38.36    39.66
# 3    JPM           JPMorgan Chase & Co.      USD   87.51      83.51    87.91
# 4    WFC          Wells Fargo & Company      USD   27.22      26.47    27.53
# 5    AXP       American Express Company      USD   76.66      77.06    79.12
# 6    BLK                BlackRock, Inc.      USD  426.53     408.18   433.87
# 7     GS  The Goldman Sachs Group, Inc.      USD  149.93     143.02   150.45
# 8     MS                 Morgan Stanley      USD   33.90      31.34    34.00
# 9    USB                   U.S. Bancorp      USD   32.67      31.60    33.08
#
#   day_low 52_week_high 52_week_low day_change  ... volume_avg      shares  \
# 0   19.59        35.72       17.95       0.80  ...  117991112  8724769792
# 1  174.23       231.61      159.50       3.78  ...   11771350  1382349952
# 2   37.30        83.11       32.00       0.72  ...   30651662  2098210048
# 3   82.96       141.10       76.91       3.15  ...   29739350  3084000000
# 4   26.40        54.75       25.11       0.65  ...   45007400  4089400064
# 5   75.83       138.13       67.00      -0.75  ...    8369462   805777984
# 6  406.19       576.81      323.98      16.99  ...    1383250   154828000
# 7  141.67       250.46      130.85       4.64  ...    5510687   343873984
# 8   31.25        57.57       27.20       2.28  ...   24777962  1532400000
# 9   31.45        61.11       28.59       0.74  ...   13092125  1521260032
#
#        stock_exchange_long stock_exchange_short timezone     timezone_name  \
# 0  New York Stock Exchange                 NYSE      EDT  America/New_York
# 1  New York Stock Exchange                 NYSE      EDT  America/New_York
# 2  New York Stock Exchange                 NYSE      EDT  America/New_York
# 3  New York Stock Exchange                 NYSE      EDT  America/New_York
# 4  New York Stock Exchange                 NYSE      EDT  America/New_York
# 5  New York Stock Exchange                 NYSE      EDT  America/New_York
# 6  New York Stock Exchange                 NYSE      EDT  America/New_York
# 7  New York Stock Exchange                 NYSE      EDT  America/New_York
# 8  New York Stock Exchange                 NYSE      EDT  America/New_York
# 9  New York Stock Exchange                 NYSE      EDT  America/New_York
#
#   gmt_offset      last_trade_time     pe       eps
# 0     -14400  2020-04-02 16:02:00   7.48      2.75
# 1     -14400  2020-04-02 16:02:00   0.00  49828.45
# 2     -14400  2020-04-02 16:02:00   4.88      8.04
# 3     -14400  2020-04-02 16:02:00   8.16     10.72
# 4     -14400  2020-04-02 16:02:00   6.72      4.05
# 5     -14400  2020-04-02 16:02:00   9.59      7.99
# 6     -14400  2020-04-02 16:02:00  15.00     28.43
# 7     -14400  2020-04-02 16:02:00   7.13     21.03
# 8     -14400  2020-04-02 16:02:00   6.53      5.19
# 9     -14400  2020-04-02 16:02:00   7.85      4.16
#
# [10 rows x 24 columns]

# %%
# REAL TIME MARKET DATA - SECTION #3:
# Set #3:    'TFC,CB,SPGI,PNC,SCHW'
# Set #4:    'MMC,AON,ICE,MCO,PGR'
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #3: 'symbol': 'TFC,CB,SPGI,PNC,SCHW',
params = {'symbol': 'TFC,CB,SPGI,PNC,SCHW',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'CB',
#    'name': 'Chubb Limited',
#    'currency': 'USD',
#    'price': '105.93',
#    'price_open': '103.68',
#    'day_high': '108.38',
#    'day_low': '103.42',
#    '52_week_high': '167.74',
#    '52_week_low': '87.35',
#    'day_change': '1.76',
#    'change_pct': '1.69',
#    'close_yesterday': '104.17',
#    'market_cap': '47870615552',
#    'volume': '2198083',
#    'volume_avg': '3453000',
#    'shares': '451972000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '10.91',
#    'eps': '9.71'},
#   {'symbol': 'PNC',
#    'name': 'The PNC Financial Services Group, Inc.',
#    'currency': 'USD',
#    'price': '90.73',
#    'price_open': '87.33',
#    'day_high': '91.97',
#    'day_low': '85.86',
#    '52_week_high': '161.79',
#    '52_week_low': '79.41',
#    'day_change': '3.38',
#    'change_pct': '3.87',
#    'close_yesterday': '87.35',
#    'market_cap': '38898401280',
#    'volume': '2904410',
#    'volume_avg': '3668187',
#    'shares': '428727008',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '7.97',
#    'eps': '11.38'},
#   {'symbol': 'SCHW',
#    'name': 'The Charles Schwab Corporation',
#    'currency': 'USD',
#    'price': '34.39',
#    'price_open': '32.42',
#    'day_high': '34.57',
#    'day_low': '32.32',
#    '52_week_high': '51.65',
#    '52_week_low': '28.00',
#    'day_change': '1.43',
#    'change_pct': '4.34',
#    'close_yesterday': '32.96',
#    'market_cap': '44269559808',
#    'volume': '14310341',
#    'volume_avg': '15395650',
#    'shares': '1287280000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '12.88',
#    'eps': '2.67'},
#   {'symbol': 'SPGI',
#    'name': 'S&P Global Inc.',
#    'currency': 'USD',
#    'price': '241.34',
#    'price_open': '233.34',
#    'day_high': '241.70',
#    'day_low': '230.11',
#    '52_week_high': '312.94',
#    '52_week_low': '186.06',
#    'day_change': '7.01',
#    'change_pct': '2.99',
#    'close_yesterday': '234.33',
#    'market_cap': '58148220928',
#    'volume': '1602397',
#    'volume_avg': '2876037',
#    'shares': '240939008',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '28.06',
#    'eps': '8.60'},
#   {'symbol': 'TFC',
#    'name': 'Truist Financial Corporation',
#    'currency': 'USD',
#    'price': '28.48',
#    'price_open': '28.29',
#    'day_high': '29.61',
#    'day_low': '27.63',
#    '52_week_high': '56.92',
#    '52_week_low': '24.01',
#    'day_change': '0.01',
#    'change_pct': '0.04',
#    'close_yesterday': '28.47',
#    'market_cap': '38305599488',
#    'volume': '7789106',
#    'volume_avg': '10093237',
#    'shares': '1344999936',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': 'N/A',
#    'eps': 'N/A'}]}

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__TFC_CB_SPGI_PNC_SCHW__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_three = ['TFC', 'CB', 'SPGI', 'PNC', 'SCHW']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_three:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Create "stocks_response_json_list_three_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_three_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_three_df" DataFrame columns:
stocks_response_json_list_three_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_three_df
# Out:
#   symbol                                    name currency   price price_open  \
# 0     CB                           Chubb Limited      USD  105.93     103.68
# 1    PNC  The PNC Financial Services Group, Inc.      USD   90.73      87.33
# 2   SCHW          The Charles Schwab Corporation      USD   34.39      32.42
# 3   SPGI                         S&P Global Inc.      USD  241.34     233.34
# 4    TFC            Truist Financial Corporation      USD   28.48      28.29
#
#   day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0   108.38  103.42       167.74       87.35       1.76  ...    3453000
# 1    91.97   85.86       161.79       79.41       3.38  ...    3668187
# 2    34.57   32.32        51.65       28.00       1.43  ...   15395650
# 3   241.70  230.11       312.94      186.06       7.01  ...    2876037
# 4    29.61   27.63        56.92       24.01       0.01  ...   10093237
#
#        shares      stock_exchange_long stock_exchange_short timezone  \
# 0   451972000  New York Stock Exchange                 NYSE      EDT
# 1   428727008  New York Stock Exchange                 NYSE      EDT
# 2  1287280000  New York Stock Exchange                 NYSE      EDT
# 3   240939008  New York Stock Exchange                 NYSE      EDT
# 4  1344999936  New York Stock Exchange                 NYSE      EDT
#
#       timezone_name gmt_offset      last_trade_time     pe    eps
# 0  America/New_York     -14400  2020-04-02 16:02:00  10.91   9.71
# 1  America/New_York     -14400  2020-04-02 16:02:00   7.97  11.38
# 2  America/New_York     -14400  2020-04-02 16:02:00  12.88   2.67
# 3  America/New_York     -14400  2020-04-02 16:02:00  28.06   8.60
# 4  America/New_York     -14400  2020-04-02 16:02:00    N/A    N/A
#
# [5 rows x 24 columns]

# %%
# Append "stocks_response_json_list_three_df" to the end of "appended_one_thru_two_df":
appended_one_thru_three_df = appended_one_thru_two_df.append(stocks_response_json_list_three_df, ignore_index = True)
appended_one_thru_three_df
# Out:
#    symbol                                    name currency   price price_open  \
# 0     BAC             Bank of America Corporation      USD   20.57      19.65
# 1   BRK.B                 Berkshire Hathaway Inc.      USD  179.73     175.00
# 2       C                          Citigroup Inc.      USD   39.23      38.36
# 3     JPM                    JPMorgan Chase & Co.      USD   87.51      83.51
# 4     WFC                   Wells Fargo & Company      USD   27.22      26.47
# 5     AXP                American Express Company      USD   76.66      77.06
# 6     BLK                         BlackRock, Inc.      USD  426.53     408.18
# 7      GS           The Goldman Sachs Group, Inc.      USD  149.93     143.02
# 8      MS                          Morgan Stanley      USD   33.90      31.34
# 9     USB                            U.S. Bancorp      USD   32.67      31.60
# 10     CB                           Chubb Limited      USD  105.93     103.68
# 11    PNC  The PNC Financial Services Group, Inc.      USD   90.73      87.33
# 12   SCHW          The Charles Schwab Corporation      USD   34.39      32.42
# 13   SPGI                         S&P Global Inc.      USD  241.34     233.34
# 14    TFC            Truist Financial Corporation      USD   28.48      28.29
#
#    day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0     20.79   19.59        35.72       17.95       0.80  ...  117991112
# 1    180.31  174.23       231.61      159.50       3.78  ...   11771350
# 2     39.66   37.30        83.11       32.00       0.72  ...   30651662
# 3     87.91   82.96       141.10       76.91       3.15  ...   29739350
# 4     27.53   26.40        54.75       25.11       0.65  ...   45007400
# 5     79.12   75.83       138.13       67.00      -0.75  ...    8369462
# 6    433.87  406.19       576.81      323.98      16.99  ...    1383250
# 7    150.45  141.67       250.46      130.85       4.64  ...    5510687
# 8     34.00   31.25        57.57       27.20       2.28  ...   24777962
# 9     33.08   31.45        61.11       28.59       0.74  ...   13092125
# 10   108.38  103.42       167.74       87.35       1.76  ...    3453000
# 11    91.97   85.86       161.79       79.41       3.38  ...    3668187
# 12    34.57   32.32        51.65       28.00       1.43  ...   15395650
# 13   241.70  230.11       312.94      186.06       7.01  ...    2876037
# 14    29.61   27.63        56.92       24.01       0.01  ...   10093237
#
#         shares      stock_exchange_long stock_exchange_short timezone  \
# 0   8724769792  New York Stock Exchange                 NYSE      EDT
# 1   1382349952  New York Stock Exchange                 NYSE      EDT
# 2   2098210048  New York Stock Exchange                 NYSE      EDT
# 3   3084000000  New York Stock Exchange                 NYSE      EDT
# 4   4089400064  New York Stock Exchange                 NYSE      EDT
# 5    805777984  New York Stock Exchange                 NYSE      EDT
# 6    154828000  New York Stock Exchange                 NYSE      EDT
# 7    343873984  New York Stock Exchange                 NYSE      EDT
# 8   1532400000  New York Stock Exchange                 NYSE      EDT
# 9   1521260032  New York Stock Exchange                 NYSE      EDT
# 10   451972000  New York Stock Exchange                 NYSE      EDT
# 11   428727008  New York Stock Exchange                 NYSE      EDT
# 12  1287280000  New York Stock Exchange                 NYSE      EDT
# 13   240939008  New York Stock Exchange                 NYSE      EDT
# 14  1344999936  New York Stock Exchange                 NYSE      EDT
#
#        timezone_name gmt_offset      last_trade_time     pe       eps
# 0   America/New_York     -14400  2020-04-02 16:02:00   7.48      2.75
# 1   America/New_York     -14400  2020-04-02 16:02:00   0.00  49828.45
# 2   America/New_York     -14400  2020-04-02 16:02:00   4.88      8.04
# 3   America/New_York     -14400  2020-04-02 16:02:00   8.16     10.72
# 4   America/New_York     -14400  2020-04-02 16:02:00   6.72      4.05
# 5   America/New_York     -14400  2020-04-02 16:02:00   9.59      7.99
# 6   America/New_York     -14400  2020-04-02 16:02:00  15.00     28.43
# 7   America/New_York     -14400  2020-04-02 16:02:00   7.13     21.03
# 8   America/New_York     -14400  2020-04-02 16:02:00   6.53      5.19
# 9   America/New_York     -14400  2020-04-02 16:02:00   7.85      4.16
# 10  America/New_York     -14400  2020-04-02 16:02:00  10.91      9.71
# 11  America/New_York     -14400  2020-04-02 16:02:00   7.97     11.38
# 12  America/New_York     -14400  2020-04-02 16:02:00  12.88      2.67
# 13  America/New_York     -14400  2020-04-02 16:02:00  28.06      8.60
# 14  America/New_York     -14400  2020-04-02 16:02:00    N/A       N/A
#
# [15 rows x 24 columns]

# %%
# REAL TIME MARKET DATA - SECTION #4:
# Set #4:    'MMC,AON,ICE,MCO,PGR'
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #4: 'symbol': 'MMC,AON,ICE,MCO,PGR',
params = {'symbol': 'MMC,AON,ICE,MCO,PGR',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'AON',
#    'name': 'Aon plc',
#    'currency': 'USD',
#    'price': '157.26',
#    'price_open': '152.35',
#    'day_high': '159.57',
#    'day_low': '152.00',
#    '52_week_high': '238.19',
#    '52_week_low': '143.93',
#    'day_change': '3.58',
#    'change_pct': '2.33',
#    'close_yesterday': '153.68',
#    'market_cap': '36376125440',
#    'volume': '1499700',
#    'volume_avg': '2262562',
#    'shares': '231312000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '24.70',
#    'eps': '6.37'},
#   {'symbol': 'ICE',
#    'name': 'Intercontinental Exchange, Inc.',
#    'currency': 'USD',
#    'price': '81.14',
#    'price_open': '79.00',
#    'day_high': '81.39',
#    'day_low': '77.17',
#    '52_week_high': '101.93',
#    '52_week_low': '63.51',
#    'day_change': '1.83',
#    'change_pct': '2.31',
#    'close_yesterday': '79.31',
#    'market_cap': '44557053952',
#    'volume': '2722899',
#    'volume_avg': '4698950',
#    'shares': '549137984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '23.73',
#    'eps': '3.42'},
#   {'symbol': 'MCO',
#    'name': "Moody's Corporation",
#    'currency': 'USD',
#    'price': '206.72',
#    'price_open': '195.40',
#    'day_high': '206.97',
#    'day_low': '192.00',
#    '52_week_high': '287.25',
#    '52_week_low': '164.19',
#    'day_change': '9.17',
#    'change_pct': '4.64',
#    'close_yesterday': '197.55',
#    'market_cap': '38699638784',
#    'volume': '1004151',
#    'volume_avg': '1451100',
#    'shares': '187208000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '27.86',
#    'eps': '7.42'},
#   {'symbol': 'MMC',
#    'name': 'Marsh & McLennan Companies, Inc.',
#    'currency': 'USD',
#    'price': '82.75',
#    'price_open': '83.69',
#    'day_high': '84.22',
#    'day_low': '81.10',
#    '52_week_high': '119.88',
#    '52_week_low': '74.33',
#    'day_change': '0.73',
#    'change_pct': '0.89',
#    'close_yesterday': '82.02',
#    'market_cap': '41697558528',
#    'volume': '2399633',
#    'volume_avg': '3569550',
#    'shares': '503897984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '24.27',
#    'eps': '3.41'},
#   {'symbol': 'PGR',
#    'name': 'The Progressive Corporation',
#    'currency': 'USD',
#    'price': '76.56',
#    'price_open': '71.36',
#    'day_high': '77.54',
#    'day_low': '71.74',
#    '52_week_high': '84.96',
#    '52_week_low': '62.18',
#    'day_change': '4.20',
#    'change_pct': '5.80',
#    'close_yesterday': '72.36',
#    'market_cap': '44810412032',
#    'volume': '3704559',
#    'volume_avg': '4788012',
#    'shares': '585297984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '11.39',
#    'eps': '6.72'}]}

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__MMC_AON_ICE_MCO_PGR__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_four = ['MMC', 'AON', 'ICE', 'MCO', 'PGR']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_four:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Create "stocks_response_json_list_four_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_four_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_four_df" DataFrame columns:
stocks_response_json_list_four_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_four_df
# Out:
#   symbol                              name currency   price price_open  \
# 0    AON                           Aon plc      USD  157.26     152.35
# 1    ICE   Intercontinental Exchange, Inc.      USD   81.14      79.00
# 2    MCO               Moody's Corporation      USD  206.72     195.40
# 3    MMC  Marsh & McLennan Companies, Inc.      USD   82.75      83.69
# 4    PGR       The Progressive Corporation      USD   76.56      71.36
#
#   day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0   159.57  152.00       238.19      143.93       3.58  ...    2262562
# 1    81.39   77.17       101.93       63.51       1.83  ...    4698950
# 2   206.97  192.00       287.25      164.19       9.17  ...    1451100
# 3    84.22   81.10       119.88       74.33       0.73  ...    3569550
# 4    77.54   71.74        84.96       62.18       4.20  ...    4788012
#
#       shares      stock_exchange_long stock_exchange_short timezone  \
# 0  231312000  New York Stock Exchange                 NYSE      EDT
# 1  549137984  New York Stock Exchange                 NYSE      EDT
# 2  187208000  New York Stock Exchange                 NYSE      EDT
# 3  503897984  New York Stock Exchange                 NYSE      EDT
# 4  585297984  New York Stock Exchange                 NYSE      EDT
#
#       timezone_name gmt_offset      last_trade_time     pe   eps
# 0  America/New_York     -14400  2020-04-02 16:02:00  24.70  6.37
# 1  America/New_York     -14400  2020-04-02 16:02:00  23.73  3.42
# 2  America/New_York     -14400  2020-04-02 16:02:00  27.86  7.42
# 3  America/New_York     -14400  2020-04-02 16:02:00  24.27  3.41
# 4  America/New_York     -14400  2020-04-02 16:02:00  11.39  6.72
#
# [5 rows x 24 columns]

# %%
# Append "stocks_response_json_list_four_df" to the end of "appended_one_thru_three_df":
appended_one_thru_four_df = appended_one_thru_three_df.append(stocks_response_json_list_four_df, ignore_index = True)
appended_one_thru_four_df
# Out:
#    symbol                                    name currency   price price_open  \
# 0     BAC             Bank of America Corporation      USD   20.57      19.65
# 1   BRK.B                 Berkshire Hathaway Inc.      USD  179.73     175.00
# 2       C                          Citigroup Inc.      USD   39.23      38.36
# 3     JPM                    JPMorgan Chase & Co.      USD   87.51      83.51
# 4     WFC                   Wells Fargo & Company      USD   27.22      26.47
# 5     AXP                American Express Company      USD   76.66      77.06
# 6     BLK                         BlackRock, Inc.      USD  426.53     408.18
# 7      GS           The Goldman Sachs Group, Inc.      USD  149.93     143.02
# 8      MS                          Morgan Stanley      USD   33.90      31.34
# 9     USB                            U.S. Bancorp      USD   32.67      31.60
# 10     CB                           Chubb Limited      USD  105.93     103.68
# 11    PNC  The PNC Financial Services Group, Inc.      USD   90.73      87.33
# 12   SCHW          The Charles Schwab Corporation      USD   34.39      32.42
# 13   SPGI                         S&P Global Inc.      USD  241.34     233.34
# 14    TFC            Truist Financial Corporation      USD   28.48      28.29
# 15    AON                                 Aon plc      USD  157.26     152.35
# 16    ICE         Intercontinental Exchange, Inc.      USD   81.14      79.00
# 17    MCO                     Moody's Corporation      USD  206.72     195.40
# 18    MMC        Marsh & McLennan Companies, Inc.      USD   82.75      83.69
# 19    PGR             The Progressive Corporation      USD   76.56      71.36
#
#    day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0     20.79   19.59        35.72       17.95       0.80  ...  117991112
# 1    180.31  174.23       231.61      159.50       3.78  ...   11771350
# 2     39.66   37.30        83.11       32.00       0.72  ...   30651662
# 3     87.91   82.96       141.10       76.91       3.15  ...   29739350
# 4     27.53   26.40        54.75       25.11       0.65  ...   45007400
# 5     79.12   75.83       138.13       67.00      -0.75  ...    8369462
# 6    433.87  406.19       576.81      323.98      16.99  ...    1383250
# 7    150.45  141.67       250.46      130.85       4.64  ...    5510687
# 8     34.00   31.25        57.57       27.20       2.28  ...   24777962
# 9     33.08   31.45        61.11       28.59       0.74  ...   13092125
# 10   108.38  103.42       167.74       87.35       1.76  ...    3453000
# 11    91.97   85.86       161.79       79.41       3.38  ...    3668187
# 12    34.57   32.32        51.65       28.00       1.43  ...   15395650
# 13   241.70  230.11       312.94      186.06       7.01  ...    2876037
# 14    29.61   27.63        56.92       24.01       0.01  ...   10093237
# 15   159.57  152.00       238.19      143.93       3.58  ...    2262562
# 16    81.39   77.17       101.93       63.51       1.83  ...    4698950
# 17   206.97  192.00       287.25      164.19       9.17  ...    1451100
# 18    84.22   81.10       119.88       74.33       0.73  ...    3569550
# 19    77.54   71.74        84.96       62.18       4.20  ...    4788012
#
#         shares      stock_exchange_long stock_exchange_short timezone  \
# 0   8724769792  New York Stock Exchange                 NYSE      EDT
# 1   1382349952  New York Stock Exchange                 NYSE      EDT
# 2   2098210048  New York Stock Exchange                 NYSE      EDT
# 3   3084000000  New York Stock Exchange                 NYSE      EDT
# 4   4089400064  New York Stock Exchange                 NYSE      EDT
# 5    805777984  New York Stock Exchange                 NYSE      EDT
# 6    154828000  New York Stock Exchange                 NYSE      EDT
# 7    343873984  New York Stock Exchange                 NYSE      EDT
# 8   1532400000  New York Stock Exchange                 NYSE      EDT
# 9   1521260032  New York Stock Exchange                 NYSE      EDT
# 10   451972000  New York Stock Exchange                 NYSE      EDT
# 11   428727008  New York Stock Exchange                 NYSE      EDT
# 12  1287280000  New York Stock Exchange                 NYSE      EDT
# 13   240939008  New York Stock Exchange                 NYSE      EDT
# 14  1344999936  New York Stock Exchange                 NYSE      EDT
# 15   231312000  New York Stock Exchange                 NYSE      EDT
# 16   549137984  New York Stock Exchange                 NYSE      EDT
# 17   187208000  New York Stock Exchange                 NYSE      EDT
# 18   503897984  New York Stock Exchange                 NYSE      EDT
# 19   585297984  New York Stock Exchange                 NYSE      EDT
#
#        timezone_name gmt_offset      last_trade_time     pe       eps
# 0   America/New_York     -14400  2020-04-02 16:02:00   7.48      2.75
# 1   America/New_York     -14400  2020-04-02 16:02:00   0.00  49828.45
# 2   America/New_York     -14400  2020-04-02 16:02:00   4.88      8.04
# 3   America/New_York     -14400  2020-04-02 16:02:00   8.16     10.72
# 4   America/New_York     -14400  2020-04-02 16:02:00   6.72      4.05
# 5   America/New_York     -14400  2020-04-02 16:02:00   9.59      7.99
# 6   America/New_York     -14400  2020-04-02 16:02:00  15.00     28.43
# 7   America/New_York     -14400  2020-04-02 16:02:00   7.13     21.03
# 8   America/New_York     -14400  2020-04-02 16:02:00   6.53      5.19
# 9   America/New_York     -14400  2020-04-02 16:02:00   7.85      4.16
# 10  America/New_York     -14400  2020-04-02 16:02:00  10.91      9.71
# 11  America/New_York     -14400  2020-04-02 16:02:00   7.97     11.38
# 12  America/New_York     -14400  2020-04-02 16:02:00  12.88      2.67
# 13  America/New_York     -14400  2020-04-02 16:02:00  28.06      8.60
# 14  America/New_York     -14400  2020-04-02 16:02:00    N/A       N/A
# 15  America/New_York     -14400  2020-04-02 16:02:00  24.70      6.37
# 16  America/New_York     -14400  2020-04-02 16:02:00  23.73      3.42
# 17  America/New_York     -14400  2020-04-02 16:02:00  27.86      7.42
# 18  America/New_York     -14400  2020-04-02 16:02:00  24.27      3.41
# 19  America/New_York     -14400  2020-04-02 16:02:00  11.39      6.72
#
# [20 rows x 24 columns]

# %%
# REAL TIME MARKET DATA - SECTION #5:
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #5: 'symbol': 'MET,AIG,COF,BK,ALL',
params = {'symbol': 'MET,AIG,COF,BK,ALL',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'AIG',
#    'name': 'American International Group, Inc.',
#    'currency': 'USD',
#    'price': '21.25',
#    'price_open': '21.11',
#    'day_high': '22.83',
#    'day_low': '21.08',
#    '52_week_high': '58.66',
#    '52_week_low': '16.07',
#    'day_change': '-0.36',
#    'change_pct': '-1.67',
#    'close_yesterday': '21.61',
#    'market_cap': '18302412800',
#    'volume': '9288064',
#    'volume_avg': '10573912',
#    'shares': '861289984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '5.68',
#    'eps': '3.74'},
#   {'symbol': 'ALL',
#    'name': 'The Allstate Corporation',
#    'currency': 'USD',
#    'price': '85.79',
#    'price_open': '86.27',
#    'day_high': '89.73',
#    'day_low': '84.04',
#    '52_week_high': '125.92',
#    '52_week_low': '64.13',
#    'day_change': '-0.61',
#    'change_pct': '-0.71',
#    'close_yesterday': '86.40',
#    'market_cap': '27188051968',
#    'volume': '2414199',
#    'volume_avg': '3013562',
#    'shares': '318791008',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '6.11',
#    'eps': '14.03'},
#   {'symbol': 'BK',
#    'name': 'The Bank of New York Mellon Corporation',
#    'currency': 'USD',
#    'price': '33.64',
#    'price_open': '32.40',
#    'day_high': '33.95',
#    'day_low': '32.07',
#    '52_week_high': '53.61',
#    '52_week_low': '26.40',
#    'day_change': '0.94',
#    'change_pct': '2.87',
#    'close_yesterday': '32.70',
#    'market_cap': '29773115392',
#    'volume': '5338201',
#    'volume_avg': '7880625',
#    'shares': '885051008',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '7.46',
#    'eps': '4.51'},
#   {'symbol': 'COF',
#    'name': 'Capital One Financial Corporation',
#    'currency': 'USD',
#    'price': '43.93',
#    'price_open': '43.75',
#    'day_high': '45.86',
#    'day_low': '43.08',
#    '52_week_high': '107.59',
#    '52_week_low': '38.00',
#    'day_change': '-0.75',
#    'change_pct': '-1.68',
#    'close_yesterday': '44.68',
#    'market_cap': '20081414144',
#    'volume': '5369061',
#    'volume_avg': '5579587',
#    'shares': '465720992',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '3.98',
#    'eps': '11.05'},
#   {'symbol': 'MET',
#    'name': 'MetLife, Inc.',
#    'currency': 'USD',
#    'price': '28.05',
#    'price_open': '27.48',
#    'day_high': '28.98',
#    'day_low': '27.44',
#    '52_week_high': '53.28',
#    '52_week_low': '22.85',
#    'day_change': '0.15',
#    'change_pct': '0.54',
#    'close_yesterday': '27.90',
#    'market_cap': '25688973312',
#    'volume': '7066237',
#    'volume_avg': '9715900',
#    'shares': '915299968',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-04-02 16:02:00',
#    'pe': '4.63',
#    'eps': '6.06'}]}

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__MET_AIG_COF_BK_ALL__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_five = ['MET', 'AIG', 'COF', 'BK', 'ALL']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_five:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Create "stocks_response_json_list_five_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_five_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_five_df" DataFrame columns:
stocks_response_json_list_five_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_five_df
# Out:
#   symbol                                     name currency  price price_open  \
# 0    AIG       American International Group, Inc.      USD  21.25      21.11
# 1    ALL                 The Allstate Corporation      USD  85.79      86.27
# 2     BK  The Bank of New York Mellon Corporation      USD  33.64      32.40
# 3    COF        Capital One Financial Corporation      USD  43.93      43.75
# 4    MET                            MetLife, Inc.      USD  28.05      27.48
#
#   day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0    22.83   21.08        58.66       16.07      -0.36  ...   10573912
# 1    89.73   84.04       125.92       64.13      -0.61  ...    3013562
# 2    33.95   32.07        53.61       26.40       0.94  ...    7880625
# 3    45.86   43.08       107.59       38.00      -0.75  ...    5579587
# 4    28.98   27.44        53.28       22.85       0.15  ...    9715900
#
#       shares      stock_exchange_long stock_exchange_short timezone  \
# 0  861289984  New York Stock Exchange                 NYSE      EDT
# 1  318791008  New York Stock Exchange                 NYSE      EDT
# 2  885051008  New York Stock Exchange                 NYSE      EDT
# 3  465720992  New York Stock Exchange                 NYSE      EDT
# 4  915299968  New York Stock Exchange                 NYSE      EDT
#
#       timezone_name gmt_offset      last_trade_time    pe    eps
# 0  America/New_York     -14400  2020-04-02 16:02:00  5.68   3.74
# 1  America/New_York     -14400  2020-04-02 16:02:00  6.11  14.03
# 2  America/New_York     -14400  2020-04-02 16:02:00  7.46   4.51
# 3  America/New_York     -14400  2020-04-02 16:02:00  3.98  11.05
# 4  America/New_York     -14400  2020-04-02 16:02:00  4.63   6.06
#
# [5 rows x 24 columns]

# %%
# Append "stocks_response_json_list_five_df" to the end of "appended_one_thru_four_df":
appended_one_thru_five_df = appended_one_thru_four_df.append(stocks_response_json_list_five_df, ignore_index = True)
WTD_API_RealTimeMarketData_FullStockList_df = appended_one_thru_five_df
WTD_API_RealTimeMarketData_FullStockList_df
# Out:
#    symbol                                     name currency   price  \
# 0     BAC              Bank of America Corporation      USD   20.57
# 1   BRK.B                  Berkshire Hathaway Inc.      USD  179.73
# 2       C                           Citigroup Inc.      USD   39.23
# 3     JPM                     JPMorgan Chase & Co.      USD   87.51
# 4     WFC                    Wells Fargo & Company      USD   27.22
# 5     AXP                 American Express Company      USD   76.66
# 6     BLK                          BlackRock, Inc.      USD  426.53
# 7      GS            The Goldman Sachs Group, Inc.      USD  149.93
# 8      MS                           Morgan Stanley      USD   33.90
# 9     USB                             U.S. Bancorp      USD   32.67
# 10     CB                            Chubb Limited      USD  105.93
# 11    PNC   The PNC Financial Services Group, Inc.      USD   90.73
# 12   SCHW           The Charles Schwab Corporation      USD   34.39
# 13   SPGI                          S&P Global Inc.      USD  241.34
# 14    TFC             Truist Financial Corporation      USD   28.48
# 15    AON                                  Aon plc      USD  157.26
# 16    ICE          Intercontinental Exchange, Inc.      USD   81.14
# 17    MCO                      Moody's Corporation      USD  206.72
# 18    MMC         Marsh & McLennan Companies, Inc.      USD   82.75
# 19    PGR              The Progressive Corporation      USD   76.56
# 20    AIG       American International Group, Inc.      USD   21.25
# 21    ALL                 The Allstate Corporation      USD   85.79
# 22     BK  The Bank of New York Mellon Corporation      USD   33.64
# 23    COF        Capital One Financial Corporation      USD   43.93
# 24    MET                            MetLife, Inc.      USD   28.05
#
#    price_open day_high day_low 52_week_high 52_week_low day_change  ...  \
# 0       19.65    20.79   19.59        35.72       17.95       0.80  ...
# 1      175.00   180.31  174.23       231.61      159.50       3.78  ...
# 2       38.36    39.66   37.30        83.11       32.00       0.72  ...
# 3       83.51    87.91   82.96       141.10       76.91       3.15  ...
# 4       26.47    27.53   26.40        54.75       25.11       0.65  ...
# 5       77.06    79.12   75.83       138.13       67.00      -0.75  ...
# 6      408.18   433.87  406.19       576.81      323.98      16.99  ...
# 7      143.02   150.45  141.67       250.46      130.85       4.64  ...
# 8       31.34    34.00   31.25        57.57       27.20       2.28  ...
# 9       31.60    33.08   31.45        61.11       28.59       0.74  ...
# 10     103.68   108.38  103.42       167.74       87.35       1.76  ...
# 11      87.33    91.97   85.86       161.79       79.41       3.38  ...
# 12      32.42    34.57   32.32        51.65       28.00       1.43  ...
# 13     233.34   241.70  230.11       312.94      186.06       7.01  ...
# 14      28.29    29.61   27.63        56.92       24.01       0.01  ...
# 15     152.35   159.57  152.00       238.19      143.93       3.58  ...
# 16      79.00    81.39   77.17       101.93       63.51       1.83  ...
# 17     195.40   206.97  192.00       287.25      164.19       9.17  ...
# 18      83.69    84.22   81.10       119.88       74.33       0.73  ...
# 19      71.36    77.54   71.74        84.96       62.18       4.20  ...
# 20      21.11    22.83   21.08        58.66       16.07      -0.36  ...
# 21      86.27    89.73   84.04       125.92       64.13      -0.61  ...
# 22      32.40    33.95   32.07        53.61       26.40       0.94  ...
# 23      43.75    45.86   43.08       107.59       38.00      -0.75  ...
# 24      27.48    28.98   27.44        53.28       22.85       0.15  ...
#
#    volume_avg      shares      stock_exchange_long stock_exchange_short  \
# 0   117991112  8724769792  New York Stock Exchange                 NYSE
# 1    11771350  1382349952  New York Stock Exchange                 NYSE
# 2    30651662  2098210048  New York Stock Exchange                 NYSE
# 3    29739350  3084000000  New York Stock Exchange                 NYSE
# 4    45007400  4089400064  New York Stock Exchange                 NYSE
# 5     8369462   805777984  New York Stock Exchange                 NYSE
# 6     1383250   154828000  New York Stock Exchange                 NYSE
# 7     5510687   343873984  New York Stock Exchange                 NYSE
# 8    24777962  1532400000  New York Stock Exchange                 NYSE
# 9    13092125  1521260032  New York Stock Exchange                 NYSE
# 10    3453000   451972000  New York Stock Exchange                 NYSE
# 11    3668187   428727008  New York Stock Exchange                 NYSE
# 12   15395650  1287280000  New York Stock Exchange                 NYSE
# 13    2876037   240939008  New York Stock Exchange                 NYSE
# 14   10093237  1344999936  New York Stock Exchange                 NYSE
# 15    2262562   231312000  New York Stock Exchange                 NYSE
# 16    4698950   549137984  New York Stock Exchange                 NYSE
# 17    1451100   187208000  New York Stock Exchange                 NYSE
# 18    3569550   503897984  New York Stock Exchange                 NYSE
# 19    4788012   585297984  New York Stock Exchange                 NYSE
# 20   10573912   861289984  New York Stock Exchange                 NYSE
# 21    3013562   318791008  New York Stock Exchange                 NYSE
# 22    7880625   885051008  New York Stock Exchange                 NYSE
# 23    5579587   465720992  New York Stock Exchange                 NYSE
# 24    9715900   915299968  New York Stock Exchange                 NYSE
#
#    timezone     timezone_name gmt_offset      last_trade_time     pe       eps
# 0       EDT  America/New_York     -14400  2020-04-02 16:02:00   7.48      2.75
# 1       EDT  America/New_York     -14400  2020-04-02 16:02:00   0.00  49828.45
# 2       EDT  America/New_York     -14400  2020-04-02 16:02:00   4.88      8.04
# 3       EDT  America/New_York     -14400  2020-04-02 16:02:00   8.16     10.72
# 4       EDT  America/New_York     -14400  2020-04-02 16:02:00   6.72      4.05
# 5       EDT  America/New_York     -14400  2020-04-02 16:02:00   9.59      7.99
# 6       EDT  America/New_York     -14400  2020-04-02 16:02:00  15.00     28.43
# 7       EDT  America/New_York     -14400  2020-04-02 16:02:00   7.13     21.03
# 8       EDT  America/New_York     -14400  2020-04-02 16:02:00   6.53      5.19
# 9       EDT  America/New_York     -14400  2020-04-02 16:02:00   7.85      4.16
# 10      EDT  America/New_York     -14400  2020-04-02 16:02:00  10.91      9.71
# 11      EDT  America/New_York     -14400  2020-04-02 16:02:00   7.97     11.38
# 12      EDT  America/New_York     -14400  2020-04-02 16:02:00  12.88      2.67
# 13      EDT  America/New_York     -14400  2020-04-02 16:02:00  28.06      8.60
# 14      EDT  America/New_York     -14400  2020-04-02 16:02:00    N/A       N/A
# 15      EDT  America/New_York     -14400  2020-04-02 16:02:00  24.70      6.37
# 16      EDT  America/New_York     -14400  2020-04-02 16:02:00  23.73      3.42
# 17      EDT  America/New_York     -14400  2020-04-02 16:02:00  27.86      7.42
# 18      EDT  America/New_York     -14400  2020-04-02 16:02:00  24.27      3.41
# 19      EDT  America/New_York     -14400  2020-04-02 16:02:00  11.39      6.72
# 20      EDT  America/New_York     -14400  2020-04-02 16:02:00   5.68      3.74
# 21      EDT  America/New_York     -14400  2020-04-02 16:02:00   6.11     14.03
# 22      EDT  America/New_York     -14400  2020-04-02 16:02:00   7.46      4.51
# 23      EDT  America/New_York     -14400  2020-04-02 16:02:00   3.98     11.05
# 24      EDT  America/New_York     -14400  2020-04-02 16:02:00   4.63      6.06
#
# [25 rows x 24 columns]

# %%
# Create DataFrame "dates_readable_df", with data column named "Date_Readable", containing data from the
# "WTD_API_RealTimeMarketData_FullStockList_df" DataFrame's "last_trade_time" column:
dates_readable_df = pd.DataFrame({'Date_Readable': WTD_API_RealTimeMarketData_FullStockList_df['last_trade_time']})
dates_readable_df
# Out:
#           Date_Readable
# 0   2020-04-02 16:02:00
# 1   2020-04-02 16:02:00
# 2   2020-04-02 16:02:00
# 3   2020-04-02 16:02:00
# 4   2020-04-02 16:02:00
# 5   2020-04-02 16:02:00
# 6   2020-04-02 16:02:00
# 7   2020-04-02 16:02:00
# 8   2020-04-02 16:02:00
# 9   2020-04-02 16:02:00
# 10  2020-04-02 16:02:00
# 11  2020-04-02 16:02:00
# 12  2020-04-02 16:02:00
# 13  2020-04-02 16:02:00
# 14  2020-04-02 16:02:00
# 15  2020-04-02 16:02:00
# 16  2020-04-02 16:02:00
# 17  2020-04-02 16:02:00
# 18  2020-04-02 16:02:00
# 19  2020-04-02 16:02:00
# 20  2020-04-02 16:02:00
# 21  2020-04-02 16:02:00
# 22  2020-04-02 16:02:00
# 23  2020-04-02 16:02:00
# 24  2020-04-02 16:02:00

# %%
# Send the contents of the "dates_readable_df" DataFrame, column "Date_Readable", to a list named "dates_readable_list":
dates_readable_list = dates_readable_df['Date_Readable'].tolist()
dates_readable_list
# Out:
# ['2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00',
#  '2020-04-02 16:02:00']

# %%
# WTD - List, "dates_readable_list" - Data Type:
type(dates_readable_list)
# Out:
# list

# %%
# Initialize the "dates_datetime_list", which is to contain "python strings" from the "dates_readable_list",
# which have been converted into "datetime objects":
dates_datetime_list = []

# "For Loop" itirates through the list of readable dates (python_string_i) in "dates_readable_list":
for python_string_i in dates_readable_list:
    
    # Convert "python string" of "python_string_i", to a "datetime object" of "date_datetime_object",
    # in format of '%Y-%m-%d %H:%M:%S' (year, month, day, hour, minute, second),
    # (i.e.: datetime.datetime(2020, 4, 2, 16, 2)):
    # FORMAT: date_object = datetime.strptime(date_string, format)
    date_datetime_object = datetime.strptime(python_string_i, '%Y-%m-%d %H:%M:%S')
    
    # Append each "date_datetime_object" (datetime object: datetime.datetime) to the "dates_datetime_list":
    dates_datetime_list.append(date_datetime_object)
    
# Print "dates_datetime_list" to confirm FULL of "datetime objects":
dates_datetime_list
# Out:
# [datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2),
#  datetime.datetime(2020, 4, 2, 16, 2)]

# %%
# WTD - datetime object: datetime.datetime, "date_datetime_object" - Data Type:
type(date_datetime_object)
# Out:
# datetime.datetime

# %%
# WTD - List, "dates_datetime_list" - Data Type:
type(dates_datetime_list)
# Out:
# list

# %%
# Initialize the "dates_unix_utc_list", which is to contain "datetime objects" from the "dates_datetime_list",
# which have been converted into "python floats", where each "float" is a date and time, in "Unix time" format,
# and in the Coordinated Universal Time (UTC) "timezone":
dates_unix_utc_list = []

# Unix Time: https://en.wikipedia.org/wiki/Unix_time
# Unix time (also known as Epoch time, POSIX time, seconds since the Epoch, or UNIX Epoch time) is a system for
# describing a point in time. It is the number of seconds that have elapsed since the Unix epoch,
# that is the time 00:00:00 UTC on 1 January 1970, minus leap seconds.

# "For Loop" itirates through the list of datetime objects (datetime_object_j) in "dates_datetime_list":
for datetime_object_j in dates_datetime_list:
    
    # Convert "datetime object" of "datetime_object_j", to a "python float" of "date_unix_utc_float",
    # in format of "UTC Unix Float" (i.e.: 1585861320.0):
    # FORMAT: float = mktime(utc.localize(datetime_object).utctimetuple())
    
    date_unix_utc_float = mktime(utc.localize(datetime_object_j).utctimetuple())
    # '2020-04-02 16:02:00' --> datetime.datetime(2020, 4, 2, 16, 2) --> "1585861320.0"
    
    #date_unix_utc_float = mktime(timezone('US/Eastern').localize(datetime_object_j).utctimetuple())
    # '2020-04-02 16:02:00' --> datetime.datetime(2020, 4, 2, 16, 2) --> "1585875720.0"
    
    # Append each "date_unix_utc_float" (float) to the "dates_unix_utc_list"
    dates_unix_utc_list.append(date_unix_utc_float)
    
# Print "dates_unix_utc_list" to confirm FULL of "UTC Unix Floats":
dates_unix_utc_list
# Out:
# [1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0,
#  1585861320.0]

# %%
# WTD - (UTC Unix) Float, "date_unix_utc_float" - Data Type:
type(date_unix_utc_float)
# Out:
# float

# %%
# WTD - List, "dates_unix_utc_list" - Data Type:
type(dates_unix_utc_list)
# Out:
# list

# %%
# Insert "dates_unix_utc_list" into "WTD_API_RealTimeMarketData_FullStockList_df":
WTD_API_RealTimeMarketData_FullStockList_df.insert(22, "last_trade_time_unix_utc", dates_unix_utc_list, True)
WTD_API_RealTimeMarketData_FullStockList_df
# Out:
#    symbol                                     name currency   price  \
# 0     BAC              Bank of America Corporation      USD   20.57
# 1   BRK.B                  Berkshire Hathaway Inc.      USD  179.73
# 2       C                           Citigroup Inc.      USD   39.23
# 3     JPM                     JPMorgan Chase & Co.      USD   87.51
# 4     WFC                    Wells Fargo & Company      USD   27.22
# 5     AXP                 American Express Company      USD   76.66
# 6     BLK                          BlackRock, Inc.      USD  426.53
# 7      GS            The Goldman Sachs Group, Inc.      USD  149.93
# 8      MS                           Morgan Stanley      USD   33.90
# 9     USB                             U.S. Bancorp      USD   32.67
# 10     CB                            Chubb Limited      USD  105.93
# 11    PNC   The PNC Financial Services Group, Inc.      USD   90.73
# 12   SCHW           The Charles Schwab Corporation      USD   34.39
# 13   SPGI                          S&P Global Inc.      USD  241.34
# 14    TFC             Truist Financial Corporation      USD   28.48
# 15    AON                                  Aon plc      USD  157.26
# 16    ICE          Intercontinental Exchange, Inc.      USD   81.14
# 17    MCO                      Moody's Corporation      USD  206.72
# 18    MMC         Marsh & McLennan Companies, Inc.      USD   82.75
# 19    PGR              The Progressive Corporation      USD   76.56
# 20    AIG       American International Group, Inc.      USD   21.25
# 21    ALL                 The Allstate Corporation      USD   85.79
# 22     BK  The Bank of New York Mellon Corporation      USD   33.64
# 23    COF        Capital One Financial Corporation      USD   43.93
# 24    MET                            MetLife, Inc.      USD   28.05
#
#    price_open day_high day_low 52_week_high 52_week_low day_change  ...  \
# 0       19.65    20.79   19.59        35.72       17.95       0.80  ...
# 1      175.00   180.31  174.23       231.61      159.50       3.78  ...
# 2       38.36    39.66   37.30        83.11       32.00       0.72  ...
# 3       83.51    87.91   82.96       141.10       76.91       3.15  ...
# 4       26.47    27.53   26.40        54.75       25.11       0.65  ...
# 5       77.06    79.12   75.83       138.13       67.00      -0.75  ...
# 6      408.18   433.87  406.19       576.81      323.98      16.99  ...
# 7      143.02   150.45  141.67       250.46      130.85       4.64  ...
# 8       31.34    34.00   31.25        57.57       27.20       2.28  ...
# 9       31.60    33.08   31.45        61.11       28.59       0.74  ...
# 10     103.68   108.38  103.42       167.74       87.35       1.76  ...
# 11      87.33    91.97   85.86       161.79       79.41       3.38  ...
# 12      32.42    34.57   32.32        51.65       28.00       1.43  ...
# 13     233.34   241.70  230.11       312.94      186.06       7.01  ...
# 14      28.29    29.61   27.63        56.92       24.01       0.01  ...
# 15     152.35   159.57  152.00       238.19      143.93       3.58  ...
# 16      79.00    81.39   77.17       101.93       63.51       1.83  ...
# 17     195.40   206.97  192.00       287.25      164.19       9.17  ...
# 18      83.69    84.22   81.10       119.88       74.33       0.73  ...
# 19      71.36    77.54   71.74        84.96       62.18       4.20  ...
# 20      21.11    22.83   21.08        58.66       16.07      -0.36  ...
# 21      86.27    89.73   84.04       125.92       64.13      -0.61  ...
# 22      32.40    33.95   32.07        53.61       26.40       0.94  ...
# 23      43.75    45.86   43.08       107.59       38.00      -0.75  ...
# 24      27.48    28.98   27.44        53.28       22.85       0.15  ...
#
#         shares      stock_exchange_long stock_exchange_short timezone  \
# 0   8724769792  New York Stock Exchange                 NYSE      EDT
# 1   1382349952  New York Stock Exchange                 NYSE      EDT
# 2   2098210048  New York Stock Exchange                 NYSE      EDT
# 3   3084000000  New York Stock Exchange                 NYSE      EDT
# 4   4089400064  New York Stock Exchange                 NYSE      EDT
# 5    805777984  New York Stock Exchange                 NYSE      EDT
# 6    154828000  New York Stock Exchange                 NYSE      EDT
# 7    343873984  New York Stock Exchange                 NYSE      EDT
# 8   1532400000  New York Stock Exchange                 NYSE      EDT
# 9   1521260032  New York Stock Exchange                 NYSE      EDT
# 10   451972000  New York Stock Exchange                 NYSE      EDT
# 11   428727008  New York Stock Exchange                 NYSE      EDT
# 12  1287280000  New York Stock Exchange                 NYSE      EDT
# 13   240939008  New York Stock Exchange                 NYSE      EDT
# 14  1344999936  New York Stock Exchange                 NYSE      EDT
# 15   231312000  New York Stock Exchange                 NYSE      EDT
# 16   549137984  New York Stock Exchange                 NYSE      EDT
# 17   187208000  New York Stock Exchange                 NYSE      EDT
# 18   503897984  New York Stock Exchange                 NYSE      EDT
# 19   585297984  New York Stock Exchange                 NYSE      EDT
# 20   861289984  New York Stock Exchange                 NYSE      EDT
# 21   318791008  New York Stock Exchange                 NYSE      EDT
# 22   885051008  New York Stock Exchange                 NYSE      EDT
# 23   465720992  New York Stock Exchange                 NYSE      EDT
# 24   915299968  New York Stock Exchange                 NYSE      EDT
#
#        timezone_name gmt_offset      last_trade_time last_trade_time_unix_utc  \
# 0   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 1   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 2   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 3   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 4   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 5   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 6   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 7   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 8   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 9   America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 10  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 11  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 12  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 13  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 14  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 15  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 16  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 17  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 18  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 19  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 20  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 21  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 22  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 23  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
# 24  America/New_York     -14400  2020-04-02 16:02:00             1.585861e+09
#
#        pe       eps
# 0    7.48      2.75
# 1    0.00  49828.45
# 2    4.88      8.04
# 3    8.16     10.72
# 4    6.72      4.05
# 5    9.59      7.99
# 6   15.00     28.43
# 7    7.13     21.03
# 8    6.53      5.19
# 9    7.85      4.16
# 10  10.91      9.71
# 11   7.97     11.38
# 12  12.88      2.67
# 13  28.06      8.60
# 14    N/A       N/A
# 15  24.70      6.37
# 16  23.73      3.42
# 17  27.86      7.42
# 18  24.27      3.41
# 19  11.39      6.72
# 20   5.68      3.74
# 21   6.11     14.03
# 22   7.46      4.51
# 23   3.98     11.05
# 24   4.63      6.06
#
# [25 rows x 25 columns]

# %%
# Export the "WTD_API_RealTimeMarketData_FullStockList_df" to a CSV file named
# "WTD_API_FULL_STOCK_LIST_RealTimeMarketData.csv":
output_data_file = "./output_data/WTD_API_FULL_STOCK_LIST_RealTimeMarketData.csv"
WTD_API_RealTimeMarketData_FullStockList_df.to_csv(output_data_file, index = False, header = True)
